# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %%
class stack:
    def __init__(self):
        self.top=None
        
    def isEmpty(self):
        if self.top==None:
            return True
        return False
